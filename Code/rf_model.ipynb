# %% [markdown]
# # Random Forest on UFC
# This notebook aims to provide a model for the win/lose question with RF, tuned with `sklearn.GridSearchCV`.

# %%
import pandas as pd
import numpy as np
from pprint import pprint
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold, GridSearchCV
from sklearn.metrics import accuracy_score

# %%
# !readlink . -f
# Out:
# /home/zebalgebra/School/DAB/Team-7/Code

# %%
fp = "/home/zebalgebra/School/DAB/Team-7/Data/Cleaned/"
# !eza -l (readlink $fp -f) # or replace eza by ls if no eza installed
# Out:
# .rw-r--r-- 625k zebalgebra 12 Apr 22:36 df_records.csv
# .rw-r--r-- 3.4M zebalgebra 12 Apr 22:36 fight_data.csv
# .rw-r--r-- 5.3M zebalgebra 12 Apr 22:36 fighter_agg.csv
# .rw-r--r-- 6.5k zebalgebra 12 Apr 22:36 ppv_data.csv

# %%
[rec_df, fight_df, agg_df] = [
    pd.read_csv(f"{fp}{x}.csv")
    for x in ["df_records", "fight_data", "fighter_agg"]
]
df_all = [rec_df, fight_df, agg_df]

# %%
df = pd.concat(
    [
        df_all[0],
        df_all[2].iloc[:, 2:]
    ],
    axis=1
).merge(
    right=df_all[1][["Winner", "date"]],
    right_on=["Winner", "date"],
    left_on=["fighter", "date"],
    how="outer"
)
df["is_winner"] = 1 - df["Winner"].isna()
df = df.drop(columns="Winner").iloc[:, 2:]
df = df.fillna(0)
df_x, df_y = df.iloc[:, :-1], df.iloc[:, -1]

# %% [markdown]
# ## GridSearchCV

# %%
# %%time

clf = RandomForestClassifier(random_state=6203)

gscv_opts = {
    "estimator": clf,
    "param_grid": {
        "n_estimators": [80],
        "max_depth": [4, 6, 8, 12, 15],
        "max_features": ['sqrt', 'log2'],
        "min_samples_split": [2, 10, 30],
        "min_samples_leaf": [1, 3, 6]
    },
    "scoring": "accuracy",
    "cv": 10,
    "verbose": 2
}

gscv = GridSearchCV(**gscv_opts)
gscv.fit(df_x, df_y)
res = gscv.cv_results_
bi = gscv.best_index_
# Out:
# Fitting 10 folds for each of 90 candidates, totalling 900 fits
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.6s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.6s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.6s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.6s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.7s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.5s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.5s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.6s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.7s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.6s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.6s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.6s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.6s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.6s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.6s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   2.1s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.6s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.5s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.6s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.6s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.6s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.7s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.5s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.5s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.6s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.4s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.3s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=4, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.1s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   2.2s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   2.3s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   2.2s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   2.2s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   2.2s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   2.2s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   2.2s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   2.3s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   2.2s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   2.1s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   2.1s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   2.1s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   2.1s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   2.1s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   2.1s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   2.1s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   2.1s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   2.1s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   2.1s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   2.1s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   2.1s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   2.1s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   2.1s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   2.1s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   2.1s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   2.1s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   2.1s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   2.0s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   2.1s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.7s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.7s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.7s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.7s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.7s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.7s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.7s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.7s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.8s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.6s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.6s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.7s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.6s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.6s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.6s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.6s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   1.6s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.6s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.6s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   1.6s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.6s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.6s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.6s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.6s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.6s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.6s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   1.6s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.6s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.9s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.5s
# [CV] END max_depth=6, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   1.5s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   2.4s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   2.4s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   2.4s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   2.4s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   2.4s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   2.5s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   2.4s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   2.6s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   2.5s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   2.7s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   2.7s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   2.8s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   3.1s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   3.1s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   3.1s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   3.0s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   3.0s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   2.7s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   3.0s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   3.2s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   3.2s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   3.2s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   3.1s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   3.3s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   3.4s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   3.3s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   3.2s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   3.3s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   3.6s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   4.0s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   3.7s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   3.4s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   3.4s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   3.3s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   3.4s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   3.2s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   3.2s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   3.1s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   3.1s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   3.0s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   3.0s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   3.0s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   3.0s
# [CV] END max_depth=8, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   3.0s
# ...
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   3.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   3.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   3.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   3.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   3.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   3.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   3.8s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   4.1s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   4.2s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   4.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   3.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   4.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   4.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   4.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   4.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   4.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   4.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   4.5s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   4.3s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   3.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   3.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   3.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   3.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   3.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   3.7s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   4.0s
# [CV] END max_depth=15, max_features=sqrt, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   4.6s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   4.0s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   4.0s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   3.9s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   4.0s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   4.0s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   4.1s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   4.0s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   3.4s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   3.1s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   3.1s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   3.1s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   3.0s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   3.1s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   3.0s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   3.0s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   3.1s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   3.0s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   3.1s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   3.1s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=10, n_estimators=80; total time=   3.0s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   2.9s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   2.9s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   3.3s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   3.5s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   3.4s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   3.4s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   3.4s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   3.4s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   3.5s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=1, min_samples_split=30, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   3.7s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   3.7s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   3.7s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   3.7s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   3.7s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=80; total time=   3.7s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   3.5s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   3.5s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   3.5s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   3.5s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   3.5s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   3.5s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=10, n_estimators=80; total time=   3.6s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   3.4s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   3.3s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   3.3s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   3.5s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   3.4s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   3.4s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   3.4s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   3.3s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   3.4s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=3, min_samples_split=30, n_estimators=80; total time=   3.5s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   3.3s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   2.9s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   2.9s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   2.9s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   2.9s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   2.9s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   2.9s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   2.9s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   3.0s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=2, n_estimators=80; total time=   3.0s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   2.9s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   2.9s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   2.9s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   2.9s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   3.0s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   3.0s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   3.0s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   3.0s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   3.0s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=10, n_estimators=80; total time=   3.0s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   2.9s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   2.9s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   2.9s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   2.9s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   2.9s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   2.9s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   2.9s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   2.9s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   2.9s
# [CV] END max_depth=15, max_features=log2, min_samples_leaf=6, min_samples_split=30, n_estimators=80; total time=   2.9s
# CPU times: user 36min 1s, sys: 1.06 s, total: 36min 2s
# Wall time: 36min 9s

# %%
print(f"""
best params: {res["params"][bi]}
best mean test score: {res["mean_test_score"][bi]}
""")
# Out:
# best params: {'max_depth': 4, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 80}
# best mean test score: 0.5505868534777381
